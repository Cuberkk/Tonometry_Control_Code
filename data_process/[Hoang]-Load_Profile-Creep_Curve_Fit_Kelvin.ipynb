# %%
# %matplotlib widget
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import os
from scipy.signal import savgol_filter, medfilt

# %%
RECORDED_TIME = 60

# %%
def data_read_cvsv(csv_path):
    CSV_COL_TIME  = "Time (s)"    # header for time in seconds
    CSV_COL_DEPTH = "Position (mm)"  # header for depth in mm
    df = pd.read_csv(csv_path)

    # # Time range'
    # t1 = 0.75
    # t2 = t1 + RECORDED_TIME

    t_raw = df[CSV_COL_TIME].to_numpy(dtype=float)
    h_mm_raw = df[CSV_COL_DEPTH].to_numpy(dtype=float)

    t = df[CSV_COL_TIME].to_numpy(dtype=float)
    h_mm = df[CSV_COL_DEPTH].to_numpy(dtype=float)

    h_mm -= h_mm[0]

    # t0 = t[h_mm > 1.e-2][0]
    # t -= t0

    t1 = 0.75
    t2 = t1 + RECORDED_TIME
    
    h_mm = np.abs(h_mm)  # Ensure depth is positive
    h_mm = medfilt(h_mm, kernel_size=5)  # Apply median filter to depth data

    h_mm = h_mm[(t >= t1) & (t <= t2)]
    t = t[(t >= t1) & (t <= t2)]

    # t -= t[0]  # Set initial time to zero
    
    return h_mm, t, h_mm_raw, t_raw

# %%
#input parameters
# 
P0=8.8515 #Applied constant force in N
a= 6.25 #Radius of the flat-circular indenter in millimeter


csv_path_1 = r'recorded_data/Black_Gel/_Creep_1.5min__Recover_0.75min/trial_10.csv'
csv_path_2 = f"biomomentum_data_2/Creep_1.csv"

SCALE=(P0)/(2*a) #N/mm

# Data Loading Data
h_mm, t, h_mm_raw, t_raw = data_read_cvsv(csv_path_1)
h_mm2, t2, h_mm2_raw, t2_raw = data_read_cvsv(csv_path_2)

# Saving controls
SAVE_PLOTS = True
SAVE_CSV   = False
#SAVE_DIR   = r"C:\Users\kxg554\Documents\Paper\Creep Curve Fitting\Outputs"   # or: os.path.dirname(csv_path)
#os.makedirs(SAVE_DIR, exist_ok=True)

# %%
plt.figure()
plt.plot(t, h_mm, label="Tonometry Data")
# plt.plot(t_raw, h_mm_raw, label="Tonometry raw data")
plt.plot(t2, h_mm2, label="Biomomentum Data")
# plt.plot(t2_raw, h_mm2_raw, label="Biomomentum raw data")
plt.xlabel("Time (s)")
plt.ylabel("Depth (mm)")
plt.title("Creep Curve Comparison")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Creep Compliance J(t)

def J_GKV(t, E0, E1, eta1, E2, eta2):
    t = np.asarray(t, float)
    E0 = max(E0, 1e-12); E1 = max(E1, 1e-12); E2 = max(E2, 1e-12)
    eta1 = max(eta1, 1e-12); eta2 = max(eta2, 1e-12)
    tau1 = max(eta1 / E1, 1e-12)
    tau2 = max(eta2 / E2, 1e-12)
    return (1/E0)+ (1/E1)*(1 - np.exp(-t/tau1)) + (1/E2)*(1 - np.exp(-t/tau2))

# %%
# Depth Models h(t) in mm

def h_GKV (t, E0, E1, eta1, E2, eta2):
    return SCALE*J_GKV(t, E0, E1, eta1, E2, eta2)

# %%
#  R²
def r2_score(y, yhat):
    ss_res = float(np.sum((y - yhat)**2))
    ss_tot = float(np.sum((y - np.mean(y))**2))
    return np.nan if ss_tot == 0 else 1.0 - ss_res/ss_tot

# %%
# fit (5 parameters)
def fit_GKV(t, h):
    f = h_GKV
    names  = ["E0","E1","eta1","E2","eta2"]
    # Reasonable polymer-ish guesses/bounds; tweak for your material
    p0     = (0.0284, 0.2116, 4.5451, 0.1620, 0.4454)               # MPa, MPa, MPa·s, MPa, MPa·s
    bounds = ((0.001, 0.001, 0.001, 0.001, 0.001),
              (1e11,1e11,1e13,1e11,1e13))

    popt, _ = curve_fit(f, t, h, p0=p0, bounds=bounds, maxfev=60000)
    yfit = f(t, *popt)
    R2 = r2_score(h, yfit)
    params = {n: float(v) for n, v in zip(names, popt)}
    predict = lambda tt: f(np.asarray(tt, float), *popt)
    return params, R2, predict

# %%
#  Run fit8
params, R2, predict = fit_GKV(t, h_mm)

# Evaluate fit on RAW time steps (same time scale)
yfit_raw = predict(t)                    # fits at the exact experimental times
residual = h_mm - yfit_raw

# %%
# Report
print("\nGeneralized Kelvin-Voigt Model with n = 2 Fitted Parameters _ Biomomentum T5")
for k, v in params.items():
    units = "MPa·s" if "eta" in k else "MPa"
    print(f"  {k:>6s} = {v:.4f} {units}")   # 4 decimals, adjust as needed
# Out:
# Generalized Kelvin-Voigt Model with n = 2 Fitted Parameters _ Biomomentum T5
#       E0 = 0.2609 MPa
#       E1 = 2.4674 MPa
#     eta1 = 40.9292 MPa·s
#       E2 = 0.9478 MPa
#     eta2 = 1.5943 MPa·s

# %%
# derived times
tau1 = params["eta1"] / params["E1"]
tau2 = params["eta2"] / params["E2"]
print(f"  tau1   = {tau1:.4f} s")
print(f"  tau2   = {tau2:.4f} s")
print(f"  R²     = {R2:.4f}")
# Out:
#   tau1   = 16.5880 s
#   tau2   = 1.6821 s
#   R²     = 0.9989

# %%
# Plot
tt = np.linspace(0, RECORDED_TIME, 400)
plt.figure()
plt.plot(t, h_mm, "o", ms=4, label="experimental")
plt.plot(tt, predict(tt), "-", label=f"GKV (n=2) fit (R²={R2:.4f})")
plt.xlabel("Time (s)"); plt.ylabel("Depth (mm)")
plt.title("Creep: Generalized Kelvin-Voigt Model with n = 2")
plt.legend(loc="lower right"); 
plt.tight_layout()
#if SAVE_PLOTS:
#    out_svg = os.path.join(SAVE_DIR, "fit_GKV.svg")
#    plt.savefig(out_svg, dpi=600)
#    print(f"Saved plot: {out_svg}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
